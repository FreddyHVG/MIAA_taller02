# %% [markdown]
# ## Objetivo del proyecto

# %% [markdown]
# Desarrollar un modelo de aprendizaje automático que, utilizando datos abiertos de monitoreo forestal, permita clasificar la cobertura forestal en diferentes tipos de vegetación. Este modelo se integrará con MLflow para gestionar el ciclo de vida del aprendizaje automático y se desplegará mediante un servicio web utilizando Flask.

# %% [markdown]
# ## Montar drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Navegar hasta la carpeta donde se va a clonar el repositorio

# %%
# %cd /content/drive/MyDrive/MIAA/Clases/Herramientas IA/Prácticas
# Out:
# /content/drive/MyDrive/MIAA/Clases/Herramientas IA/Prácticas

# %%
# !git clone https://github.com/FreddyHVG/MIAA_taller02.git
# Out:
# Cloning into 'MIAA_taller02'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.
